# %% [markdown]
# # W2A1 [Hello World!]
# Máy tính giao tiếp với con người thông qua các thiết bị thu nhận các yêu cầu của người dùng
# (input devices) như bàn phím, con chuột, microphone và các thiết bị hiển thị kết quả tính
# toán (output devices) như màn hình, loa. Trong bài này, chúng ta sẽ làm việc với thiết bị
# hiển thị kết quả tính toán đơn giản nhất, đó là màn hình văn bản (text screen). Màn hình văn
# bản được dùng để hiển thị các thông tin dưới dạng văn bản từ chữ cái (characters), chữ số
# (digits) đến các dòng văn bản (text line), các đoạn văn bản (text paragraph). Trong đa số
# trường hợp, màn hình văn bản còn được gọi là thiết bị xuất chuẩn (standard output device)
# bởi vì nó là thiết bị hiển thị và đầu ra mặc định của các chương trình.
# Trong python hàm print() được dùng để hiển thị thông tin ra màn hình (console), nó là một
# trong những công cụ quan trọng nhất để: Hiển thị kết quả cho người dùng, Kiểm tra, debug
# chương trình khi lập trình, Xuất thông tin định dạng đẹp... Cú pháp cơ bản của hàm:
# print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False).
# Các đối số hay dùng:
# '- *objects: Chuỗi, số, danh sách, v.v... cần in ra.
# '- sep: Dấu phân cách giữa các đối tượng (mặc định là khoảng trắng ' ').
# '- end: Ký tự kết thúc dòng (mặc định là xuống dòng '\n').
# '- flush: Ép ghi ra màn hình ngay lập tức.
# print() là một trong những hàm được Python cung cấp sẵn, bạn có thể dùng nó mà không cần
# import thư viện gì hết.
# Nó được định nghĩa trong mô-đun builtins, là mô-đun mặc định luôn được nạp khi Python
# chạy.
# Như vậy, toàn bộ một chương trình in ra dòng chữ "Hello World!" như sau: print("Hello
# World!").
# Hãy viết chương trình in ra dòng chữ "Hello World!" vào ô dưới đây rồi ấn Nộp bài để kiểm
# tra xem bạn đã biết cách in một thông báo ra màn hình.

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # W2A2 [User Input]
# Hàm input() trong Python là một hàm dùng để nhận dữ liệu từ người dùng thông qua bàn
# phím, hàm này luôn trả về dữ liệu kiểu chuỗi (str).
# Viết chương trình nhận đầu vào là tên người từ bàn phím và in ra màn hình lời chào tương
# ứng.

# %%
ten = input()
print(f'Xin chao {ten}!')
# Out:
# Xin chao Linh

# %% [markdown]
# # W2A3 [ModAndDiv]
# Viết chương trình nhận vào hai số nguyên a, b từ bàn phím. In ra tổng, hiệu, tích, phần
# nguyên, phần dư và kết quả chia thực của phép chia a cho b (lấy đến 2 chữ số phần thập
# phân) theo định dạng đúng của output

# %%
a, b = map(int, input().split())
tong = a + b
hieu = a-b
tich = a*b
phannguyen = a//b
phandu = a%b
chiathuc = a/b
print(f'a = {a}\nb = {b}\nTổng: {tong}\nHiệu: {hieu}\nTích: {tich}\nPhần nguyên: {phannguyen}\nPhần dư: {phandu}\nChia thực: {chiathuc}')
# Out:
# a = 2
# b = 3
# Tổng: 5
# Hiệu: -1
# Tích: 6
# Phần nguyên: 0
# Phần dư: 2
# Chia thực: 0.6666666666666666

# %% [markdown]
# # W2A4 [AverageOfSix]
# Viết chương trình python để tính điểm trung bình môn học của một học sinh trong lớp. Có tổng cộng
# 6 đầu điểm: a1, b1, c1, a2, b2, a3. Trong đó:
# • Các điểm a1, b1, c1 được nhân hệ số 1,
# • Các điểm a2, b2 được nhân hệ số 2,
# • Điểm a3 được nhân hệ số 3.
# Công thức tính điểm trung bình là: TB=((a1+b1+c1)+(a2+b2)×2+a3×3)/10
# Đầu vào: Trong bài tập này, dữ liệu vào chỉ gồm duy nhất một dòng bao gồm 6 số thể hiện cho 6
# đầu điểm a1, b1, c1, a2, b2, a3 theo đúng thứ tự đó. Trong đó, hai đầu điểm liên tiếp nhau sẽ được
# phân tách nhau bởi duy nhất 1 dấu cách.
# Đầu ra: Đầu ra là giá trị điểm trung bình môn học của 6 môn học, lấy đến 1 chữ số phần thập phân.

# %%
a1, b1, c1, a2, b2, a3 = map(float, input().strip().split())
he_so_1 = a1+b1+c1
he_so_2 = (a2+b2)*2
he_so_3 = a3*3
diem_trung_binh = (he_so_1 + he_so_2 + he_so_3)/10
print(f'Điểm trung bình môn học: {diem_trung_binh:.1f}')

# %% [markdown]
# # W2A5 [Exponentiation]
# Trong Python, phép toán mũ (luỹ thừa) được viết bằng **. Ví dụ: để tính 2^3 bạn viết 2**3, và kết
# quả là 8. Cơ số và số mũ có thể có kiểu float hoặc int. Trong bài này bạn hãy nhập vào hai số a, b
# (int) cách nhau một dấu cách, tính và in ra kết quả a mũ b.

# %%
a, b = map(int, input().strip().split())
result = a**b
print(result)
# Out:
# 8

# %% [markdown]
# # W2A6 [StringDataType]
# “Chuỗi” trong python là các kí tự được xâu lại với nhau như những hạt trên một chiếc dây chuyền.
# Chính vì thế “chuỗi” còn được gọi là “xâu”. Một chuỗi gồm các kí tự nằm trong dấu nháy đơn '' hoặc
# nháy đôi "”.• Mỗi chuỗi (str) là một chuỗi các kí tự trong bảng mã Unicode kể từ Python 3 trở đi
# (Unicode là một tiêu chuẩn mã hóa kí tự toàn cầu, cho phép biểu diễn hầu hết mọi kí tự trong tất cả
# các ngôn ngữ trên thế giới, bao gồm cả kí hiệu, biểu tượng, emoji,….). Bạn có thể dùng ord() và
# chr() để làm việc với mã Unicode.
# Hãy nhập vào một kí tự chữ cái thường ‘a’…’z’, in ra mã Unicode của nó sau đó chuyển nó thành kí
# tự hoa tương ứng, in kí tự hoa này ra màn hình.

# %%
n = input().strip()
if n == 'z':
    print("A")
elif 'a' <= n <= 'z':
    print(chr(ord(n)+1).upper())
else:
    print("Hãy nhập kí tự chữ cái thường")
if 'a' <= n <= 'z':
    print(n.upper())
else:
    print("Hãy nhập kí tự chữ cái thường")
# Out:
# G

# %% [markdown]
# # W2A7 [Operations]
# Hãy in ra kết quả của hai biểu thức sau:
# A = ((13 ** 2) * 3) + 5 và B = 13**2*3 + 5
# Chú ý: Hãy để ý phong cách viết mã của A

# %%
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print(f'A = {A}\nB = {B}')
# Out:
# A = 512
# B = 512

# %% [markdown]
# # W2A8 [CelsiusTranfer]
# Fahrenheit, hay độ F, là một thang nhiệt độ được đặt theo tên nhà vật lý người Đức Daniel
# Gabriel Fahrenheit (1686–1736). Dựa vào nhiệt độ Celcius được nhập từ bàn phím, hãy
# chuyển sang độ F theo công thức: F = 9/5*C + 32 và in ra màn hình kết quả. Kết quả làm
# tròn đến hai chữ số thập phân đằng sau dấu phẩy.

# %%
C = float(input().strip())
print(f'Nhiệt độ: F = {9/5 * C + 32:.2f}F')
# Out:
# Nhiệt độ: F = 33.8F

# %% [markdown]
# # W2A9 [ShoppingOnline]
# Sơn Tùng mua một chiếc đồng hồ Movado trên trang mua sắm trực tuyến Amazon. Chiếc
# đồng hồ có giá x USD (x nhập từ bàn phím). Bởi Amazon không vận chuyển trực tiếp về
# Việt Nam, Đạt phải trả 10 USD cho phí vận chuyển từ một nước trung gian. Khi vận chuyển
# về Việt Nam, Đạt được thông báo sẽ phải trả thêm 30% thuế xuất nhập cảnh và 10% thuế
# VAT cho chiếc đồng hồ nói trên. Viết chương trình tính tổng số tiền mà Đạt phải trả để mua
# được chiếc đồng hồ trên (USD). Kết quả làm tròn đến hai chữ số thập phân.

# %%
x = float(input().strip())
print(f" tổng số tiền mà Đạt phải trả là: {10 + 1.4 * x:.}")
# Out:
#  tổng số tiền mà Đạt phải trả là: 12.8

# %% [markdown]
# # W2A10 [Friend Names]
# Viết chương trình nhập vào tên 3 người từ bàn phím.
# In ra màn hình tên theo thứ tự đảo ngược.
# VD: input ("Bob Alice Helen") thì output: ("Hi Helen, Alice and Bob.")

# %%
names_reversed = input().strip().split()[::-1]
print(f'Hi {names_reversed[0]}, {names_reversed[1]} and {names_reversed[2]}')
# Out:
# Hi jami, tin and jju

# %% [markdown]
# # W2A11
# Viết chương trình chuyển từ giờ và phút sang giây
# Đầu vào gồm hai giá trị chứa số giờ \h và số phút \m:
# Đầu ra: In ra màn hình một dòng duy nhất số giờ và phút được chuyển sang đơn vị giây.

# %%
h = float(input().strip())
m = float(input().strip())
print(f'{h} giờ {m} phút = {h*3600+m*60} ')
# Out:
# 1.0 giờ 30.0 phút = 5400.0 phút

# %% [markdown]
# # W2A12
# Cho một khối Rubik có độ dài cạnh là n, hãy trả về số lượng miếng dán riêng lẻ cần thiết để
# bao phủ toàn bộ khối lập phương. Ví dụ, khối rubic có độ dài cạnh là 1 cần 6 miếng dán
# riêng lẻ. (Lưu ý: một khối rubic có 6 mặt)

# %%
n = int(input().strip())
if n > 0:
    s = n*n*6
    print(f'Số lượng miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương co do dai canh {n} la: {s}')
else: print('Độ dài cạnh không thể âm')
# Out:
# Số lượng miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương co do dai canh 2 la: 24

# %%
print("--- Chương trình tính miếng dán Rubik (Nhập 0 để thoát) ---")

while True:
    n = int(input("Nhập độ dài cạnh n: "))
    
    if n == 0:
        print("Đang thoát chương trình...")
        break
        
    elif n < 0:
        print("Vui lòng nhập số dương!")
        continue
        
    s = n * n * 6
    print(f"Kết quả: {s} miếng dán.")
# Out:
# --- Chương trình tính miếng dán Rubik (Nhập 0 để thoát) ---
# Kết quả: 6 miếng dán.
# Kết quả: 24 miếng dán.
# Kết quả: 54 miếng dán.
# Kết quả: 96 miếng dán.
# Kết quả: 726 miếng dán.
# Kết quả: 73926 miếng dán.
# Kết quả: 740725926 miếng dán.
# Vui lòng nhập số dương!
# Đang thoát chương trình...

# %% [markdown]
# # W2A13
# Nhập vào từ bàn phím hai số nguyên dương \a và \b, viết chương trình trả về hàng đơn vị của phép tính tích giữa \a và \b.

# %%
a, b = map(int, input().split())
if a>0 and b>0:
    tich = a*b
    print(f"Hàng đơn vị của phép tính tích là: {tich % 10}")
else:
    print('Hãy nhập số nguyên dương')
# Out:
# Hãy nhập số nguyên dương

# %% [markdown]
# # W2A14
# Viết chương trình hoán đổi giá trị giữa hai số a và b mà không cần khai báo thêm một biến/ hàm nào khác.

# %%
# a, b = map(float, input().split()) 
# a, b = b, a
# print(f'a = {a}\nb = {b}')

# a, b = map(float, input().split())
# a = a+b
# b = a-b
# a = a-b
# print(f'a = {a}\nb = {b}')

# a, b = map(float, input().split()[::-1])
# print(f'a = {a}\nb = {b}')

a, b = map(int, input().split())
a = a^b
b = a^b
a = a^b
print(f'a = {a}\nb = {b}')
# Out:
# a = 2
# b = 1

# %% [markdown]
# # W2A15
# Viết chương trình nhận vào một số nguyên dương n và trả về "số sao" thứ n. Một "số sao" là một số hình học trung tâm đại diện cho một hình lục giác có tâm (ngôi sao sáu cánh), giống như hình dạng được sử dụng trong trò chơi cờ Trung Quốc.

# %%
def tinh_so_sao(n):
    # Áp dụng công thức S_n = 6n(n - 1) + 1
    return 6 * n * (n - 1) + 1

def main():
    try:
        # Nhận đầu vào từ người dùng
        n = int(input("Nhập số nguyên dương n: "))
        
        if n <= 0:
            print("Vui lòng nhập một số nguyên dương (n > 0).")
        else:
            ket_qua = tinh_so_sao(n)
            print(f"Số sao thứ {n} là: {ket_qua}")
            
    except ValueError:
        print("Đầu vào không hợp lệ. Vui lòng nhập một số nguyên.")

if __name__ == "__main__":
    main()
# Out:
# Đầu vào không hợp lệ. Vui lòng nhập một số nguyên.

# %% [markdown]
# # W2A16
# [SeasonsInYear]
# Trong bài tập này, bạn sẽ sử dụng hàm print để in nhiều dòng ra màn hình. Có nhiều cách để
# làm việc này, cách thứ nhất là sử dụng lệnh print nhiều lần để in nhiều dòng khác nhau. Ví
# dụ, để in ra tên 4 mùa bằng tiếng Anh trên 4 dòng, bạn dùng 4 lệnh như sau:
# print("Spring")
#
# print("Summer")
# print("Autumn")
# print("Winter")
# Trong cách thứ hai, bạn sử dụng duy nhất một lệnh print và đưa liên tiếp các dòng chữ trên
# ra như sau:
# print("Spring\nSummer\nAutumn\nWinter")
# Lưu ý rằng đây là một lệnh duy nhất, khi gặp dấu ‘\n’ là một kí tự xuống dòng được in ra.
# Ngoài ra, bạn hãy tự tìm hiểu xem có còn cách nào khác không.
# Để luyện tập, hãy viết vào ô dưới đây chương trình in ra trên màn hình tên các mùa trong
# năm bằng tiếng Anh. Mỗi mùa in trên một dòng, bắt đầu từ "Spring".

# %%
print("""Spring
Summer
Autumn
Winter""")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# # W2A17
# [DrawTriangle]
# Sử dụng hàm print, bạn có thể in ra các dòng văn bản, các câu thông báo. Ngoài ra, với chút
# nghệ thuật xếp đặt (ký tự), bạn có thể vẽ nhiều hình vẽ đẹp và thú vị. Giới hạn chính là trí
# tưởng tượng của bạn.
# Trong bài này, bạn được yêu cầu viết chương trình vẽ ra một tam giác cân bằng các dấu sao
# trên 3 dòng. Hãy kết hợp việc sử dụng khoảng trắng với các dấu sao để in ra tam giác này.
# Ví dụ, đoạn mã để in 2 dòng đầu của tam giác:
# print("" * "")
# print("" *** "")
# Yêu cầu: In ra màn hình tam giác có 3 dòng như sau:
# *
# ***
# *****

# %%
# print('*')
# print('***')
# print('*****')

#print('*\n***\n*****')

print('''*
***
*****''')
# Out:
# *
# ***
# *****

# %% [markdown]
# # W2A18
# [Banner]
# Viết chương trình in ra dòng chữ "TDTT" như sau:
# ![image.png](attachment:image.png)

# %%
print('''
### # #   ### ###
 #  #  #   #   #
 #  #   #  #   #
 #  #  #   #   #
 #  # #    #   #''')
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %% [markdown]
# # W2A19 [Days of the week]
# Viết chương trình in ra các ngày trong một tuần bằng tiếng Anh. Mỗi ngày in trên một dòng
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
print('''Monday  
Tuesday 
Wednesday 
Thursday 
Friday 
Saturday 
Sunday ''')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# # W2A20
# [Months of the year]
# Viết chương trình in ra các tháng trong một năm bằng tiếng Anh. Mỗi tháng in trên một
# dòng, bắt đầu từ "January".
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
print('''January 
February 
March 
April 
May 
June 
July 
August 
September
October 
November 
December ''')
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# # W2A21
# [Ten Hello World]
# Viết chương trình in ra màn hình dòng chữ "Hello, world" 10 lần.
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world

# %%
for i in range(10):
    print('Hello, world')
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
