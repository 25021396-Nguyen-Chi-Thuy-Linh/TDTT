# %% [markdown]
# # Bài 1:
# Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu
# vi của nó.

# %%
a, b = map(float,input('Nhap vao 2 canh cua hcn').split())
print(f'Hình chữ nhật kich thuoc {a}x{b} có:\nDiện tích: {a*b}\nChu vi: {2*(a+b)}')
# Out:
# Hình chữ nhật kich thuoc 1x2 có:
# Diện tích: 2
# Chu vi: 6

# %% [markdown]
# # Bài 2:
# Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
import math
r = float(input())
print(f'Hình tròn bán kính {r} có:\nDiện tích: {(r**2)*math.pi}\nChu vi: {2*math.pi*r}')
# Out:
# Hình tròn bán kính 1 có:
# Diện tích: 3.141592653589793
# Chu vi: 6.283185307179586

# %% [markdown]
# # Bài 3 :
# Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là
# độ dài ba cạnh hay không, nếu  không thì in  ra màn  hình  'Khong la ba canh
# cua mot tam  giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân,
# Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn
# hình.

# %%
a,b,c = map(float,input().split())
if a>0 and b>0 and c>0:
    if a<b+c and b<a+c and c<a+b:
        if a==b==c: print('La ba canh cua mot tam giac deu')
        elif a**2 == b**2 + c**2 or b**2 == a**2 + c**2 or c**2 == a**2 + b**2:
            if a==b or a==c or b==c: print('la ba canh cua mot tam  giac vuong can')
            else: print('la ba canh cua mot tam  giac vuong')
        elif a==b or a==c or b==c: print("la ba canh cua mot tam  giac can")
        else: print("la ba canh cua mot tam  giac thuong")
        p = (a+b+c)/2
        s = (p*(p-a)*(p-b)*(p-c))**0.5
        chuvi = a+b+c
        print(f'tam giac co kich thuoc {a}x{b}x{c} co:\ndiện tích: {s}\nchu vi: {chuvi}')
    else: print('Khong la ba canh cua mot tam  giac')
else: print('Ba canh cua mot tam giac khong la so am')

# %% [markdown]
# # Bài 4:
# Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b = map(float,input().split())
if a!=0:
    print(f'phương trình bậc 1 {a}x + {b} = 0 co nghiem la: x = {-b/a}')
else:
    if b ==0:
        print('pt vo so nghiem')
    else:
        print('pt vo nghiem')

# %% [markdown]
# # Bài 5:
# Viết chương trình giải phương trình bậc 2 (ax**2 + bx + c = 0)

# %%
a, b, c = map(float,input().split())
if a==0:
    if b == 0:
        if c == 0:
            print('pt vô số nghiệm')
        else:
            print('pt vô nghiệm')
    else:
        print(f'pt có nghiệm là: {-c/b}')
else:
    delta = b**2 - 4*a*c
    if delta>0:
        x1 = (-b+delta**0.5)/(2*a)
        x2 = (-b-delta**0.5)/(2*a)
        print(f"pt có 2 nghiệm phân biệt:\nx1 = {x1}\nx2 = {x2}")
    elif delta == 0:
        x1=x2 = -b/(2*a)
        print(f'pt có nghiệm kép: x = {x1}')
    else:
        print('pt vô nghiệm')

# %% [markdown]
# # Bài 6:
# Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a, b, c, d = map(float,input().split())
max_val = a
if b>max_val:
    max_val = b
if c>max_val:
    max_val = c
if d>max_val:
    max_val = d
print(f'giá trị lớn nhất trong 4 số là: {max_val}')

# %% [markdown]
# # Bài 7:
# Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a, b, c, d = map(float,input().split())
min_val = a
if b<min_val:
    min_val = b
if c< min_val:
    min_val = c
if d<min_val:
    min_val = d
print(f'giá trị nhỏ nhất trong 4 số là: {min_val}')

# %% [markdown]
# # Bài 8:
# Giải hệ phương trình tuyến tính: ![image.png](attachment:image.png)

# %%
a, b,m, c, d,n = map(float,input().split())
print(f'Hệ pt:\n{a}x + {b}y = {m}\n{c}x + {d}y = {n}')
det = a*d-b*c
dx = m*d - n*b
dy = a*n - c*m
if det != 0:
    print(f'Nghiem cua hpt la:\nx = {dx/det}\ny = {dy/det}')
else:
    if dX != 0 or dy != 0:
        print('pt vo nghiem')
    else:
        print('pt vo so nghiem')

# %% [markdown]
# # Bài 9:
# Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x = float(input())
h = x // 3600
m = x%3600 // 60
s = x - h*3600 - m*60
print(f"{x} giây = {h} giờ {m} phút {s} giây")

# %% [markdown]
# # Bài 10:
# Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vào một điểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a = float(input())
b = float(input())
r = float(input())
x = float(input())
y = float(input())
print(f"đường tròn tâm ({a},{b}) bán kính {r}")

if (x-a)**2 + (y-b)**2 == r**2:
    print(f"Điểm A({x},{y}) thuộc đường tròn")
else:print(f"Điểm A({x},{y}) không thuộc đường tròn")

# %% [markdown]
# # Bài 11:
# Tính x^y (Với x, y là số thực).

# %%
x, y = map(float,input().split())
print(x**y)
